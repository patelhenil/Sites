# %%
import pandas as pd

# %%
import geopandas as gp

# %%
df = gp.read_file('sites.geojson')

# %%
df
# Out:
#           gid  source_id                             polygonid  min_level  \
# 0     5652385          0  b22bb644-45dc-48dd-a644-ba37239e2582          0
# 1     5645883          0  35fa5255-4c72-4a30-ab9b-4d9af9fd9cbb          0
# 2     5652384          0  cb71fdc1-fec5-4c0e-8396-05d746f0107d          0
# 3     5652383          0  590315c8-cf04-4b93-a66b-b472746637b2          0
# 4     5652382          0  fdfc6b32-4e78-4fb0-a45a-6a23e86b646a          0
# 5     5652381          0  5eb9cce7-aa6e-47e6-b5ad-7986e061d611          0
# 6     5652380          0  876a7fb0-ef41-4f09-a16c-c0969bdca631          0
# 7     5651560          0  852e5f74-f665-48b4-b905-b198c88d8bbc          0
# 8     5652379          0  50928f19-4c85-45fe-a2f3-66af439f6d6e          0
# 9     5652374          0  10111eea-1147-4269-9f89-c5ebf806c82b          0
# 10    5652376          0  6db8508c-9c55-4ad7-96e4-f17534fb605a          0
# 11    5652378          0  378ee06e-81fe-436e-a507-35736a8059d1          0
# ...

# %%
s1 = df['disp_name']
s = s1.str.contains('Flying J', regex=False)
print(s.sum())
flyingJ = df[s1.str.contains('Pilot', regex=False)]
print(flyingJ)
# Out:
# 256
#           gid  source_id                             polygonid  min_level  \
# 153   5651922          0  dc3a8249-62db-4b74-9be1-adb68d5f75f4          0
# 509   5648983          0  eba47382-47a8-416f-aaf1-d066907e7680          0
# 806   5651587          0  0ac38501-ecaf-4d02-9444-e0ac53b63c32          0
# 1042  5644300          0  efc0017f-f04f-4bfc-acb0-9ef5bac692d9          0
# 1043  5651396          0  e148bcb1-1ea5-47ec-8f28-9003bf269e66          0
# 1118  5651345          0  a2f44891-6efc-4296-b09b-4a6a1abfd7c8          0
# 1121  5648630          0  54c47a9e-8f99-42a5-b2bd-b44129945f7f          0
# 1571  5648360          0  f7822cef-b543-4a5d-8f40-2fabcae73d32          0
# 1572  5650891          0  7bed1d15-c22d-42ce-b547-3a912710010e          0
# 1577  5650886          0  47633ddc-d35d-49ee-a93f-e78eb11273a7          0
# 1581  5650885          0  e584bee1-e762-4559-8002-c0bc98c0d160          0
# 1603  5647476          0  43fac6c8-70b9-41e5-a02f-59754ac3e44b          0
# ...

# %%
flyingJ
# Out:
#           gid  source_id                             polygonid  min_level  \
# 153   5651922          0  dc3a8249-62db-4b74-9be1-adb68d5f75f4          0
# 509   5648983          0  eba47382-47a8-416f-aaf1-d066907e7680          0
# 806   5651587          0  0ac38501-ecaf-4d02-9444-e0ac53b63c32          0
# 1042  5644300          0  efc0017f-f04f-4bfc-acb0-9ef5bac692d9          0
# 1043  5651396          0  e148bcb1-1ea5-47ec-8f28-9003bf269e66          0
# 1118  5651345          0  a2f44891-6efc-4296-b09b-4a6a1abfd7c8          0
# 1121  5648630          0  54c47a9e-8f99-42a5-b2bd-b44129945f7f          0
# 1571  5648360          0  f7822cef-b543-4a5d-8f40-2fabcae73d32          0
# 1572  5650891          0  7bed1d15-c22d-42ce-b547-3a912710010e          0
# 1577  5650886          0  47633ddc-d35d-49ee-a93f-e78eb11273a7          0
# 1581  5650885          0  e584bee1-e762-4559-8002-c0bc98c0d160          0
# 1603  5647476          0  43fac6c8-70b9-41e5-a02f-59754ac3e44b          0
# ...

# %%
import fiona
from shapely.geometry import shape,mapping, Point, Polygon, MultiPolygon
import csv
flyingJ['geometry']
# Out:
# 3       (POLYGON ((-111.6425052575 40.1879963696, -111...
# 39      (POLYGON ((-110.7360065162 50.0562913317, -110...
# 1047    (POLYGON ((-97.1878997921 49.5708705663, -97.1...
# 1076    (POLYGON ((-112.2080159759 33.4622746555, -112...
# 1200    (POLYGON ((-110.0366493736 53.2852587972, -110...
# 1201    (POLYGON ((-113.3195654908 53.5663430174, -113...
# 1227    (POLYGON ((-115.6946633582 54.1371536515, -115...
# 1560    (POLYGON ((-112.1188699047 39.2550615905, -112...
# 1564    (POLYGON ((-99.46584648610001 27.6869457087, -...
# 1578    (POLYGON ((-81.0072577917 34.8555528132, -81.0...
# 1703    (POLYGON ((-80.8007796821 28.3737172556, -80.8...
# 1705    (POLYGON ((-121.2751469438 37.8556782757, -121...
# 1893    (POLYGON ((-119.0837616704 46.2627085097, -119...
# 2114    (POLYGON ((-80.2107095886 33.0797541962, -80.2...
# 2116    (POLYGON ((-95.19544942420001 29.7134535767, -...
# 2128    (POLYGON ((-118.4163188414 35.1278543, -118.41...
# ...

# %%
# p1 = Point(-111.6425052575,41.1879963696)
# ans = flyingJ['geometry'].contains(p1)
# sum(ans)

with open('Fuel_Locations_Heartland.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    next(readCSV)
    for row in readCSV:
        lat = float(row[29])
        lon = 0 - float(row[30]) 
        point = Point(lon, lat)
        #print(point)
        ans = flyingJ['geometry'].contains(point)
        if(sum(ans) != 0):
            print('True')
        else:
            print('False')
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
import csv

with open('Fuel_Locations_Heartland.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    next(readCSV)
    for row in readCSV:
        lat = float(row[29])
        lon = float(row[30]) 
        point = Point(lat, lon)
#         print(point)
        
#         print(ans)
#         if(sum(ans) > 0):
#             print("yes")
#         else:
#             print("No")

# %%
selection = df[0:]
for index, row in selection.iterrows():
#     print(row['geometry'])
    poly_area = row['geometry'].geom_type
    print(f"Polygon area at index {index} is: {poly_area}")
# Out:
# Polygon area at index 0 is: MultiPolygon
# Polygon area at index 1 is: MultiPolygon
# Polygon area at index 2 is: MultiPolygon
# Polygon area at index 3 is: MultiPolygon
# Polygon area at index 4 is: MultiPolygon
# Polygon area at index 5 is: MultiPolygon
# Polygon area at index 6 is: MultiPolygon
# Polygon area at index 7 is: MultiPolygon
# Polygon area at index 8 is: MultiPolygon
# Polygon area at index 9 is: MultiPolygon
# Polygon area at index 10 is: MultiPolygon
# Polygon area at index 11 is: MultiPolygon
# Polygon area at index 12 is: MultiPolygon
# Polygon area at index 13 is: MultiPolygon
# Polygon area at index 14 is: MultiPolygon
# Polygon area at index 15 is: MultiPolygon
# Polygon area at index 16 is: MultiPolygon
# Polygon area at index 17 is: MultiPolygon
# Polygon area at index 18 is: MultiPolygon
# Polygon area at index 19 is: MultiPolygon
# Polygon area at index 20 is: MultiPolygon
# Polygon area at index 21 is: MultiPolygon
# ...
